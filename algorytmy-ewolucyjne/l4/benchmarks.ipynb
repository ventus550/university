# %%
import utils
import numpy as np
import objective_functions

# %%
utils.quickplot(np.arange(10))

# %%
x = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(x, x)
utils.surfplotf(objective_functions.F1, -5, 5, 10, xaxis="uwu")
